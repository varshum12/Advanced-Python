# %% [markdown]
# ### Advanced Functions

# %%
import pandas as pd

# %%
import numpy as np

# %%
a = 3
b = 4
a+b
# Out:
# 7

# %% [markdown]
# a = 3
# b = 6
# a+b

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def add(x, y):
    """this function will give addition of two numbers"""
    z = x+ y
    return z

# %%
add(5,6)
# Out:
# 11

# %%
add(5,7)
# Out:
# 12

# %%
add('data' ,'science')
# Out:
# 'datascience'

# %%
# Type Hinting

# %% [markdown]
# ## Type Hinting
# #### multiplication of two numbers

# %%
def mul(x : int|float  , y : int|float):
    c = x*y
    return c

# %%
mul(23,4)
# Out:
# 92

# %%
mul(4.5 , 6)
# Out:
# 27.0

# %%
mul(2 , 'str')
# Out:
# 'strstr'

# %%
isinstance(2 , str)
# Out:
# False

# %%
def mul(x : int|float  , y : int|float):
    """we want  multiplication of numbers only"""
    assert isinstance(x , (int ,float)) , "Insert Int or float for x"
    assert isinstance(y , (int ,float)) ,"insert int or float for y"
    z = x*y
    return z

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(*args, sep=' ', end='\n', file=None, flush=False)
#     Prints the values to a stream, or to sys.stdout by default.
#
#     sep
#       string inserted between values, default a space.
#     end
#       string appended after the last value, default a newline.
#     file
#       a file-like object (stream); defaults to the current sys.stdout.
#     flush
#       whether to forcibly flush the stream.

# %%
help(max)
# Out:
# Help on built-in function max in module builtins:
#
# max(...)
#     max(iterable, *[, default=obj, key=func]) -> value
#     max(arg1, arg2, *args, *[, key=func]) -> value
#
#     With a single iterable argument, return its biggest item. The
#     default keyword-only argument specifies an object to return if
#     the provided iterable is empty.
#     With two or more positional arguments, return the largest argument.

# %%
help(mul)
# Out:
# Help on function mul in module __main__:
#
# mul(x: int | float, y: int | float)
#     we want  multiplication of numbers only

# %%
mul.__doc__
# Out:
# 'we want  multiplication of numbers only'

# %%
print.__doc__
# Out:
# 'Prints the values to a stream, or to sys.stdout by default.\n\n  sep\n    string inserted between values, default a space.\n  end\n    string appended after the last value, default a newline.\n  file\n    a file-like object (stream); defaults to the current sys.stdout.\n  flush\n    whether to forcibly flush the stream.'

# %%
max.__doc__
# Out:
# 'max(iterable, *[, default=obj, key=func]) -> value\nmax(arg1, arg2, *args, *[, key=func]) -> value\n\nWith a single iterable argument, return its biggest item. The\ndefault keyword-only argument specifies an object to return if\nthe provided iterable is empty.\nWith two or more positional arguments, return the largest argument.'

# %%
mul(2,3)
# Out:
# 6

# %%
mul(2,'str')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 mul(2,'str')
#
# Cell In[19], line 4, in mul(x, y)
#       2 """we want multiplication of numbers only"""
#       3 assert isinstance(x , (int ,float)) , "Insert Int or float for x"
# ----> 4 assert isinstance(y , (int ,float)) ,"insert int or float for y"
#       5 z = x*y
#       6 return z
#
# AssertionError: insert int or float for y

# %%
def mul(x : int|float  , y : int|float):
    if isinstance(x ,(int ,float)) and isinstance(y ,  (int ,float)):
        z = x*y
        print(z)
    else:
        print('Int or float value should be there')

# %%
mul(2,3)
# Out:
# 6

# %%
mul('str' ,2)
# Out:
# Int or float value should be there

# %%
def add(x, y):
    """this function will give addition of two numbers"""
    z = x+ y
    return z

# %%
add(111,111)
# Out:
# 222

# %%
add(111,111,11)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 add(111,111,11)
#
# TypeError: add() takes 2 positional arguments but 3 were given

# %%
# variable length argument -->*args

# %%
def add(*args):
    s = 0
    for i in args:
        s = s+i
    return s

# %%
add(23,4,5,6,7,8,9)
# Out:
# 62

# %%
def add(*args):
    s = 0
    for i in args:
        s = s+i
    print(s)

# %%
add(23,3,4)
# Out:
# 30

# %%
def args(*a):
    print(f"arguments:{a}")
    print(f"{a} : {type(a)}")

# %%
args(23.6,56,5,6)
# Out:
# arguments:(23.6, 56, 5, 6)
# (23.6, 56, 5, 6) : <class 'tuple'>

# %%
l1 = [12,34,56,67]

# %% [markdown]
# ### unpacking List

# %%
args(*l1)
# Out:
# arguments:(12, 34, 56, 67)
# (12, 34, 56, 67) : <class 'tuple'>

# %%
def amount(*args):
    bill_before_tax = 0
    total = 0
    
    for product , price , quantity in args:
        
        
        subtotal = price*quantity
        
        bill_before_tax +=  subtotal

    

        tax_to_pay = 0.18*bill_before_tax

     

        total = bill_before_tax+tax_to_pay
    return total

# %%
amount(('computer'  ,45000 ,2) ,('mobile' ,20000 ,1))
# Out:
# 129800.0
