# %%
num  = 87
type(num)
# Out:
# int

# %%
print(type(num))
# Out:
# <class 'int'>

# %%
num2 = 56.89
print(type(num2))
# Out:
# <class 'float'>

# %%
institute = 'ETLHIVE'
print(type(institute))
# Out:
# <class 'str'>

# %%
bool1 = True
print(type(bool1))
# Out:
# <class 'bool'>

# %%
d = {'name' : ['Seeta' , 'Geeta' ,'Neeta' ,'Sunita'] , 'occupation' : ['Prof' ,'counselour' ,'Admin' ,'data analyst'] ,
    'salary':[40000 ,25000 ,20000 ,35000]}

# %%
print(type(d))
# Out:
# <class 'dict'>

# %%
import pandas as pd

# %%
df = pd.DataFrame(d)

# %%
df
# Out:
#      name    occupation  salary
# 0   Seeta          Prof   40000
# 1   Geeta    counselour   25000
# 2   Neeta         Admin   20000
# 3  Sunita  data analyst   35000

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(type(df.name))
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ### Attributes
# - shape
# - columns
# - index
# - values
# - size

# %%
df.shape
# Out:
# (4, 3)

# %%
df.columns
# Out:
# Index(['name', 'occupation', 'salary'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
list(df.index)
# Out:
# [0, 1, 2, 3]

# %%
df.size
# Out:
# 12

# %%
df.values
# Out:
# array([['Seeta', 'Prof', 40000],
#        ['Geeta', 'counselour', 25000],
#        ['Neeta', 'Admin', 20000],
#        ['Sunita', 'data analyst', 35000]], dtype=object)

# %%
df.dtypes
# Out:
# name          object
# occupation    object
# salary         int64
# dtype: object

# %%
# functions of data
# info()
# isull()
# sum()
# mean()
# group by
# sort_values()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        4 non-null      object
#  1   occupation  4 non-null      object
#  2   salary      4 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 228.0+ bytes

# %%
df.groupby('name').salary.mean()
# Out:
# name
# Geeta     25000.0
# Neeta     20000.0
# Seeta     40000.0
# Sunita    35000.0
# Name: salary, dtype: float64

# %%
print(df.salary.mean())
# Out:
# 30000.0

# %%
print(df.salary.sum())
# Out:
# 120000

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Person :
    def __init__(self , name  , age , gender , occupation):
        self.name  = name
        self.age = age
        self.gender = gender 
        self.occupation = occupation

    def talk(self):
        print(f'Hi there  i am {self.name}')
        print(f'my age  is {self.age}')
        print(f'gender is {self.gender}')
        print(f'my occupation is {self.occupation} ')

# %%
p1 = Person(name = 'Aditi ' , age  = 23 , gender= 'female' , occupation= 'Data Engineer')

# %%
p1

# %%
p1.name
# Out:
# 'Aditi '

# %%
p1.gender
# Out:
# 'female'

# %%
p1.occupation
# Out:
# 'Data Engineer'

# %%
p1.location = 'Pune'

# %%
p1.location
# Out:
# 'Pune'

# %%
p1.talk()
# Out:
# Hi there  i am Aditi
# my age  is 23
# gender is female
# my occupation is Data Engineer

# %%
p1.occupation = 'ML engineer'

# %%
p1.occupation
# Out:
# 'ML engineer'

# %%
p1.talk()
# Out:
# Hi there  i am Aditi
# my age  is 23
# gender is female
# my occupation is ML engineer

# %%
p2 = Person("Swara" , 24 , 'Female' ,'Ai Engineer')

# %%
p2

# %%
p2.name
# Out:
# 'Swara'

# %%
p2.age
# Out:
# 24

# %%
p2.occupation
# Out:
# 'Ai Engineer'

# %%
p2.talk()
# Out:
# Hi there  i am Swara
# my age  is 24
# gender is Female
# my occupation is Ai Engineer

# %%
p3 = Person(name  = 'Umesh' ,age  =29 , gender = 'MAle'  , occupation = 'Buisness')

# %%
p3.name
# Out:
# 'Umesh'

# %%
from dataclasses import  dataclass
from typing import Literal

# %%
@dataclass
class Student:
    name : str
    age : int
    marks:float | int
    gender : Literal['Male' , 'Female']
    hobbies : list[str]

    def get_info(self):
        print(f'My name is {self.name}')
        print(f'My age is {self.age}')
        print(f'mark is {self.marks}')
        print(f' i am {self.gender}')
        print(f'My hobbies are {self.hobbies}')

# %%
s1 = Student(name = 'Sujit' , marks = 78 ,gender = 'Female' ,  age   = 17 , hobbies= ['Swimming'])

# %%
s1
# Out:
# Student(name='Sujit', age=17, marks=78, gender='Female', hobbies=['Swimming'])

# %%
s1.name
# Out:
# 'Sujit'

# %%
s1.age
# Out:
# 17

# %%
s1.marks
# Out:
# 78

# %%
s1.hobbies
# Out:
# ['Swimming']

# %%
s1.get_info()
# Out:
# My name is Sujit
# My age is 17
# mark is 78
#  i am Female
# My hobbies are ['Swimming']

# %%
s2 = Student('Swaraj' ,  7 , 89 , 'male'  , ['playing'])

# %%
s2
# Out:
# Student(name='Swaraj', age=7, marks=89, gender='male', hobbies=['playing'])

# %%
s2.gender
# Out:
# 'male'

# %%
s2.get_info()
# Out:
# My name is Swaraj
# My age is 7
# mark is 89
#  i am male
# My hobbies are ['playing']

# %% [markdown]
# ### Create Class for Bank account functionality

# %%
@dataclass
class Account:
    ac_no : int
    ac_name : str
    bal : int| float

    def check_balance(self):
        print(f'Current Account balance is {self.bal}')

    def deposit(self  , amt : int ):
        print(f'Amount of {amt} is deposited in account {self.ac_no}')
        self.bal = self.bal+amt
        self.check_balance()

    def withdraw(self , amt : int|float):
        if self.bal < amt:
            raise ValueError('Insufficiant balance')
        else:
            self.bal = self.bal - amt
            print(f'Amount of {amt} withdrawed from {self.ac_no}')
            self.check_balance()

    def transfer(self  ,  amt : int|float , ac = 'Account'):
        self.withdraw(amt)
        ac.deposit(amt)

# %%
a1 = Account(1234 ,'Priya' , 2000)

# %%
a1
# Out:
# Account(ac_no=1234, ac_name='Priya', bal=2000)

# %%
a1.deposit(4000)
# Out:
# Amount of 4000 is deposited in account 1234
# Current Account balance is 6000

# %%
a1.check_balance()
# Out:
# Current Account balance is 6000

# %%
a1.withdraw(2000)
# Out:
# Amount of 2000 withdrawed from 1234
# Current Account balance is 4000

# %%
a1.withdraw(5000)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[125], line 1
# ----> 1 a1.withdraw(5000)
#
# Cell In[119], line 17, in Account.withdraw(self, amt)
#      15 def withdraw(self , amt : int|float):
#      16     if self.bal < amt:
# ---> 17         raise ValueError('Insufficiant balance')
#      18     else:
#      19         self.bal = self.bal - amt
#
# ValueError: Insufficiant balance

# %%
a1.check_balance()
# Out:
# Current Account balance is 4000

# %%
a2 = Account(5678 , ac_name  = 'Suresh' , bal = 200)

# %%
a1.transfer(3000 , a2)
# Out:
# Amount of 3000 withdrawed from 1234
# Current Account balance is 1000
# Amount of 3000 is deposited in account 5678
# Current Account balance is 3200

# %%
a1.check_balance()
# Out:
# Current Account balance is 1000

# %%
a2.check_balance()
# Out:
# Current Account balance is 3200
